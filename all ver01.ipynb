# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\baiga\Documents\0 Final project\Solar home monthly data  2007 to 2014\SolarMonthlyData_2657Custs.csv")

# %%
df
# Out:
#          Customer ID Netwk Bill Rate Type  Consumption Month      Sum  \
# 0                  1                   SC             1.2007   31.000
# 1                  1                   SC             1.2008   31.000
# 2                  1                   SC             1.2009   31.000
# 3                  1                   SC             1.2010   31.000
# 4                  1                   PK             1.2011   31.000
# ...              ...                  ...                ...      ...
# 1378649         2768                  SGR            12.2014  254.409
# 1378650         2768                   PK            12.2014   52.251
# 1378651         2768                  PGR            12.2014  104.164
# 1378652         2768                   OP            12.2014  104.630
# 1378653         2768                  OGR            12.2014    1.428
#
#         Unit of me
# 0              DAY
# 1              DAY
# 2              DAY
# 3              DAY
# 4              DAY
# ...

# %%
df[df['Customer ID']==1]
# Out:
#      Customer ID Netwk Bill Rate Type  Consumption Month      Sum Unit of me
# 0              1                   SC             1.2007   31.000        DAY
# 1              1                   SC             1.2008   31.000        DAY
# 2              1                   SC             1.2009   31.000        DAY
# 3              1                   SC             1.2010   31.000        DAY
# 4              1                   PK             1.2011   31.000        DAY
# ..           ...                  ...                ...      ...        ...
# 549            1                   OP            12.2013  221.403        KWH
# 550            1                  OGR            12.2013    2.110        KWH
# 551            1                  OP1            12.2013  169.280        KWH
# 552            1                   PK            12.2013   48.820        KWH
# 553            1                  SGR            12.2013  428.253        KWH
#
# [554 rows x 5 columns]

# %%
len(df['Customer ID'].value_counts())
# Out:
# 2657

# %%
df[df['Customer ID']==1]['Netwk Bill Rate Type'].value_counts()
# Out:
# PK     108
# OP1     94
# SC      82
# OGR     54
# OP      54
# SH      54
# SGR     54
# PGR     54
# Name: Netwk Bill Rate Type, dtype: int64

# %% [markdown]
# *  PK: Time of Use billed days in a month (Temps d'utilisation jours facturés dans un mois)(day)
# *  OP1: Controlled Load 1 consumption
# *  SC: Block tariff consumption(KWH)
# *  SGR: Gross generation - 60c FiT(KWH)
# *  OP: Time of Use - Off Peak consumption(KWH)
# *  SH: Time of Use - Shoulder consumption(KWH)
# *  SGR: Gross generation - 60c FiT(KWH)

# %%
df[df['Customer ID']==1]['Unit of me'].value_counts()
# Out:
# KWH    459
# DAY     95
# Name: Unit of me, dtype: int64

# %%
df1=pd.read_excel(r"C:\Users\baiga\Documents\0 Final project\Solar home monthly data  2007 to 2014\Solar Monthly Data Notes.xlsx")

# %%
df1
# Out:
#     Unnamed: 0  \
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# 31         NaN
# 32         NaN
# 33         NaN
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# 38         NaN
# 39         NaN
# 40         NaN
# 41         NaN
# 42         NaN
# 43         NaN
# 44         NaN
# 45         NaN
# 46         NaN
# 47         NaN
#
#    Notes on Solar Home Monthly Electricity Data - 11 December 2015  \
# 0                                                 NaN
# ...

# %%
df1.shape
# Out:
# (48, 4)

# %%
df2=pd.read_csv(r"C:\Users\baiga\Documents\0 Final project\Solar home half-hour data - 1 July 2010 to 30 June 2011\2010-2011 Solar home electricity data.csv")

# %%
df2
# Out:
#         Customer  Generator Capacity  Postcode Consumption Category  \
# 0              1                3.78      2076                   GC
# 1              1                3.78      2076                   CL
# 2              1                3.78      2076                   GG
# 3              1                3.78      2076                   GC
# 4              1                3.78      2076                   CL
# ...          ...                 ...       ...                  ...
# 269730       300                3.36      2086                   CL
# 269731       300                3.36      2086                   GG
# 269732       300                3.36      2086                   GC
# 269733       300                3.36      2086                   CL
# 269734       300                3.36      2086                   GG
#
#              date   0:30   1:00   1:30   2:00   2:30  ...  19:30  20:00  \
# 0        1-Jul-10  0.303  0.471  0.083  0.121  0.361  ...  0.495  0.540
# ...

# %%
df[df['Customer ID']==1].head(20)
# Out:
#     Customer ID Netwk Bill Rate Type  Consumption Month   Sum Unit of me
# 0             1                   SC             1.2007  31.0        DAY
# 1             1                   SC             1.2008  31.0        DAY
# 2             1                   SC             1.2009  31.0        DAY
# 3             1                   SC             1.2010  31.0        DAY
# 4             1                   PK             1.2011  31.0        DAY
# 5             1                   PK             1.2012  31.0        DAY
# 6             1                   PK             1.2013  31.0        DAY
# 7             1                   PK             1.2014  31.0        DAY
# 8             1                   SC             2.2007  28.0        DAY
# 9             1                   SC             2.2008  29.0        DAY
# 10            1                   SC             2.2009  28.0        DAY
# 11            1                   SC             2.2010  28.0        DAY
# ...

# %%
non_solar=pd.read_csv(r"C:\Users\baiga\Documents\0 Final project\Solar home monthly data  2007 to 2014\NonSolarMonthlyData_4064Custs.csv")

# %%
non_solar
# Out:
#          Customer ID Netwk Bill Rate Type  Consumption Month      Sum  \
# 0               3001                  LVP             1.2007   31.000
# 1               3001                  LVP             1.2007  213.489
# 2               3001                   OP             1.2007  282.161
# 3               3001                  LVS             1.2007  573.745
# 4               3001                  OP1             1.2007  313.027
# ...              ...                  ...                ...      ...
# 1163013         7064                   SC            12.2013  945.171
# 1163014         7064                  OP2            12.2013    0.000
# 1163015         7064                   SC            12.2014   31.000
# 1163016         7064                   SC            12.2014  944.682
# 1163017         7064                  OP2            12.2014    0.000
#
#         Unit of me
# 0              DAY
# 1              KWH
# 2              KWH
# 3              KWH
# 4              KWH
# ...

# %%
non_solar[non_solar['Customer ID']==3001].head(20)
# Out:
#     Customer ID Netwk Bill Rate Type  Consumption Month      Sum Unit of me
# 0          3001                  LVP             1.2007   31.000        DAY
# 1          3001                  LVP             1.2007  213.489        KWH
# 2          3001                   OP             1.2007  282.161        KWH
# 3          3001                  LVS             1.2007  573.745        KWH
# 4          3001                  OP1             1.2007  313.027        KWH
# 5          3001                  LVP             1.2008   31.000        DAY
# 6          3001                   OP             1.2008  367.863        KWH
# 7          3001                  OP1             1.2008  255.583        KWH
# 8          3001                  LVS             1.2008  662.430        KWH
# 9          3001                  LVP             1.2008  200.746        KWH
# 10         3001                  LVP             1.2009   31.000        DAY
# ...

# %%
# df_schneider=pd.read_csv("energy-operation-sea-metadata0.csv")
df_schneider=pd.read_csv(r"C:\Users\baiga\Documents\0 Final project\energy-operation-sea-metadata0.csv", error_bad_lines=False, index_col=False)

# %%
df_schneider
# Out:
#        building_id                        site_name             country  \
# 0      10476_10478                        Potencial  Russian Federation
# 1    132306_132308                     BORDEAUX ACS              France
# 2        1656_7598                          Burnaby              Canada
# 3        1728_7854  Universal Enclosures Capellades               Spain
# 4        1728_7854  Universal Enclosures Capellades               Spain
# ..             ...                              ...                 ...
# 255   86020_137768     SETBT (Chartres de Bretagne)              France
# 256   86034_137764                 Grenoble - 38SS2              France
# 257   86116_137786                           PRODAX             Hungary
# 258   86172_137836                 Logistics Russia  Russian Federation
# 259     8805_84750                             SITX               China
#
#               country_code                  city  surface  occupants  \
# ...

# %%
df_2010=pd.read_csv(r"C:\Users\baiga\Documents\0 Final project\Solar home half-hour data - 1 July 2010 to 30 June 2011\2010-2011 Solar home electricity data.csv")

# %%
df_2010
# Out:
#         Customer  Generator Capacity  Postcode Consumption Category  \
# 0              1                3.78      2076                   GC
# 1              1                3.78      2076                   CL
# 2              1                3.78      2076                   GG
# 3              1                3.78      2076                   GC
# 4              1                3.78      2076                   CL
# ...          ...                 ...       ...                  ...
# 269730       300                3.36      2086                   CL
# 269731       300                3.36      2086                   GG
# 269732       300                3.36      2086                   GC
# 269733       300                3.36      2086                   CL
# 269734       300                3.36      2086                   GG
#
#              date   0:30   1:00   1:30   2:00   2:30  ...  19:30  20:00  \
# 0        1-Jul-10  0.303  0.471  0.083  0.121  0.361  ...  0.495  0.540
# ...

# %%
df_2010.isna().sum()
# Out:
# Customer                0
# Generator Capacity      0
# Postcode                0
# Consumption Category    0
# date                    0
# 0:30                    0
# 1:00                    0
# 1:30                    0
# 2:00                    0
# 2:30                    0
# 3:00                    0
# 3:30                    0
# 4:00                    0
# 4:30                    0
# 5:00                    0
# 5:30                    0
# 6:00                    0
# 6:30                    0
# 7:00                    0
# 7:30                    0
# 8:00                    0
# 8:30                    0
# 9:00                    0
# 9:30                    0
# 10:00                   0
# 10:30                   0
# 11:00                   0
# 11:30                   0
# 12:00                   0
# 12:30                   0
# 13:00                   0
# 13:30                   0
# 14:00                   0
# 14:30                   0
# 15:00                   0
# ...

# %%
df_2011=pd.read_csv(r"C:\Users\baiga\Documents\0 Final project\Solar home half-hour data - 1 July 2011 to 30 June 2012\2011-2012 Solar home electricity data v2.csv")

# %%
df_2011
# Out:
#         Customer  Generator Capacity  Postcode Consumption Category  \
# 0              1                3.78      2076                   CL
# 1              1                3.78      2076                   GC
# 2              1                3.78      2076                   GG
# 3              1                3.78      2076                   CL
# 4              1                3.78      2076                   GC
# ...          ...                 ...       ...                  ...
# 270299       300                3.36      2086                   GC
# 270300       300                3.36      2086                   GG
# 270301       300                3.36      2086                   CL
# 270302       300                3.36      2086                   GC
# 270303       300                3.36      2086                   GG
#
#               date   0:30   1:00   1:30   2:00   2:30  ...  20:00  20:30  \
# 0        1/07/2011  1.250  1.250  1.250  0.625  0.219  ...  0.000  0.000
# ...

# %%
df_2011.isna().sum()
# Out:
# Customer                     0
# Generator Capacity           0
# Postcode                     0
# Consumption Category         0
# date                         0
# 0:30                         0
# 1:00                         0
# 1:30                         0
# 2:00                         0
# 2:30                         0
# 3:00                         0
# 3:30                         0
# 4:00                         0
# 4:30                         0
# 5:00                         0
# 5:30                         0
# 6:00                         0
# 6:30                         0
# 7:00                         0
# 7:30                         0
# 8:00                         0
# 8:30                         0
# 9:00                         0
# 9:30                         0
# 10:00                        0
# 10:30                        0
# 11:00                        0
# 11:30                        0
# 12:00                        0
# 12:30                        0
# ...

# %%
df_2012=pd.read_csv(r"C:\Users\baiga\Documents\0 Final project\Solar home half-hour data - 1 July 2012 to 30 June 2013\2012-2013 Solar home electricity data v2.csv")

# %%
df_2012
# Out:
#         Customer  Generator Capacity  Postcode Consumption Category  \
# 0              1                3.78      2076                   CL
# 1              1                3.78      2076                   GC
# 2              1                3.78      2076                   GG
# 3              1                3.78      2076                   CL
# 4              1                3.78      2076                   GC
# ...          ...                 ...       ...                  ...
# 268552       300                3.36      2086                   GC
# 268553       300                3.36      2086                   GG
# 268554       300                3.36      2086                   CL
# 268555       300                3.36      2086                   GC
# 268556       300                3.36      2086                   GG
#
#               date   0:30   1:00   1:30   2:00   2:30  ...  20:00  20:30  \
# 0        1/07/2012  1.250  1.250  1.250  1.263  0.131  ...  0.000  0.000
# ...

# %%
df_2012['Row Quality'].value_counts()
# Out:
# Series([], Name: Row Quality, dtype: int64)

# %%
df_2012.isna().sum()
# Out:
# Customer                     0
# Generator Capacity           0
# Postcode                     0
# Consumption Category         0
# date                         0
# 0:30                         0
# 1:00                         0
# 1:30                         0
# 2:00                         0
# 2:30                         0
# 3:00                         0
# 3:30                         0
# 4:00                         0
# 4:30                         0
# 5:00                         0
# 5:30                         0
# 6:00                         0
# 6:30                         0
# 7:00                         0
# 7:30                         0
# 8:00                         0
# 8:30                         0
# 9:00                         0
# 9:30                         0
# 10:00                        0
# 10:30                        0
# 11:00                        0
# 11:30                        0
# 12:00                        0
# 12:30                        0
# ...

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
data = sm.datasets.engel.load_pandas().data
data
# Out:
#           income     foodexp
# 0     420.157651  255.839425
# 1     541.411707  310.958667
# 2     901.157457  485.680014
# 3     639.080229  402.997356
# 4     750.875606  495.560775
# ..           ...         ...
# 230   440.517424  306.519079
# 231   541.200597  299.199328
# 232   581.359892  468.000798
# 233   743.077243  522.601906
# 234  1057.676711  750.320163
#
# [235 rows x 2 columns]
